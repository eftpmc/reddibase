# %% [markdown]
# # Train Classifier + Extract Pairs
#
# Self-contained workflow for training the resolved-thread classifier from `threads.jsonl`, then extracting canonical `confirmed_pairs.jsonl`.

# %% [markdown]
# ## Bootstrap Repository

# %%
from pathlib import Path
import os, shutil, subprocess, sys, urllib.request

REPO_URL = 'https://github.com/eftpmc/reddibase.git'
REPO_DIR = Path.home() / 'reddibase'

def in_repo(path):
    return (path / 'requirements.txt').exists() and (path / 'framework').exists()

cwd = Path.cwd()
if in_repo(cwd):
    ROOT = cwd
else:
    if not REPO_DIR.exists():
        subprocess.check_call(['git', 'clone', REPO_URL, str(REPO_DIR)])
    ROOT = REPO_DIR

os.chdir(ROOT)
print(f'Repo root: {Path.cwd()}')
print(f'Python: {sys.executable}')

# %% [markdown]
# ## Install Dependencies

# %%
# %pip install -r requirements.txt

# %% [markdown]
# ## GPU Check

# %%
import torch
print('CUDA available:', torch.cuda.is_available())
if torch.cuda.is_available():
    print('GPU:', torch.cuda.get_device_name(0))
    print('CUDA version:', torch.version.cuda)
else:
    print('No CUDA GPU found. This notebook will work, but full training will be slow.')

# %% [markdown]
# ## Configuration

# %%
MODEL = 'tipofmyjoystick'
THREADS = Path(f'data/{MODEL}/threads.jsonl')
AUDIT = Path(f'data/{MODEL}/thread_audit.json')
CLASSIFIER_DIR = Path(f'models/{MODEL}/resolved_thread_classifier')
SMOKE_CLASSIFIER_DIR = Path(f'models/{MODEL}/resolved_thread_classifier_smoke')
PAIRS = Path(f'models/{MODEL}/confirmed_pairs.jsonl')
SMOKE_PAIRS = Path(f'models/{MODEL}/confirmed_pairs_smoke.jsonl')
HF_CLASSIFIER_REPO = 'eftpmc/reddibase-classifier'
EPOCHS = 3
BATCH_SIZE = 128
GRAD_ACCUM = 1
NUM_WORKERS = 8
THREAD_BATCH_SIZE = 512
CANDIDATE_BATCH_SIZE = 512
CLASSIFIER_MAX_LENGTH = 256
AMP_DTYPE = 'auto'  # auto, bf16, fp16, or none
print('Threads:', THREADS)
print('Classifier:', CLASSIFIER_DIR)
print('Pairs:', PAIRS)
print('Classifier Hub repo:', HF_CLASSIFIER_REPO)

# %% [markdown]
# ## Acquire Threads Artifact
#
# This notebook requires `threads.jsonl`. If it is not already in the repo, set `THREADS_SOURCE` to a local path or URL and run this cell.

# %%
# If threads.jsonl is not already present, set THREADS_SOURCE to a local path or URL.
# Examples:
# THREADS_SOURCE = '/scratch/yourname/threads.jsonl'
# THREADS_SOURCE = 'https://your-storage/threads.jsonl'
THREADS_SOURCE = ''

THREADS.parent.mkdir(parents=True, exist_ok=True)
if not THREADS.exists() and THREADS_SOURCE:
    if THREADS_SOURCE.startswith(('http://', 'https://')):
        print(f'Downloading {THREADS_SOURCE} -> {THREADS}')
        urllib.request.urlretrieve(THREADS_SOURCE, THREADS)
    else:
        src = Path(THREADS_SOURCE).expanduser()
        if not src.exists():
            raise FileNotFoundError(f'THREADS_SOURCE does not exist: {src}')
        print(f'Copying {src} -> {THREADS}')
        shutil.copyfile(src, THREADS)

if not THREADS.exists():
    raise FileNotFoundError(
        f'Missing {THREADS}. Upload/copy threads.jsonl to this path, '
        'or set THREADS_SOURCE above and rerun this cell.'
    )

print(f'Threads artifact: {THREADS.resolve()}')
print(f'Size: {THREADS.stat().st_size / (1024**3):.2f} GB')

# %% [markdown]
# ## Audit Training Signals

# %%
# !python -m scripts.audit_threads {MODEL} --threads {THREADS} --output {AUDIT}

# %% [markdown]
# ## View Audit Summary

# %%
import json
report = json.loads(AUDIT.read_text(encoding='utf-8'))
{
    'threads': report['threads'],
    'messages': report['messages'],
    'usable_weak_answer_threads': report['usable_weak_answer_threads'],
    'excluded_weak_answer_threads': report['excluded_weak_answer_threads'],
    'top_usable_weak_answers': report['top_usable_weak_answers'][:10],
}

# %% [markdown]
# ## Optional Smoke Training
#
# Use this on a new machine if you want a quick dependency/CUDA check before the full run.

# %%
# !python -m scripts.train_classifier {MODEL} --threads {THREADS} --limit 1000 --epochs 1 --batch-size 16 --grad-accum 1 --num-workers {NUM_WORKERS} --output {SMOKE_CLASSIFIER_DIR}

# %% [markdown]
# ## Full Classifier Training

# %%
# !python -m scripts.train_classifier {MODEL} --threads {THREADS} --epochs {EPOCHS} --batch-size {BATCH_SIZE} --grad-accum {GRAD_ACCUM} --num-workers {NUM_WORKERS} --output {CLASSIFIER_DIR}

# %% [markdown]
# ## Optional Pair Extraction Smoke Test

# %%
# !python -m scripts.build_dataset {MODEL} --threads {THREADS} --classifier {CLASSIFIER_DIR} --limit 5000 --thread-batch-size {THREAD_BATCH_SIZE} --candidate-batch-size {CANDIDATE_BATCH_SIZE} --max-length {CLASSIFIER_MAX_LENGTH} --amp-dtype {AMP_DTYPE} --output {SMOKE_PAIRS}

# %% [markdown]
# ## Full Pair Extraction

# %%
# !python -m scripts.build_dataset {MODEL} --threads {THREADS} --classifier {CLASSIFIER_DIR} --thread-batch-size {THREAD_BATCH_SIZE} --candidate-batch-size {CANDIDATE_BATCH_SIZE} --max-length {CLASSIFIER_MAX_LENGTH} --amp-dtype {AMP_DTYPE} --output {PAIRS}

# %% [markdown]
# ## Pair Count

# %%
if not PAIRS.exists():
    raise FileNotFoundError(PAIRS)
pair_count = sum(1 for _ in PAIRS.open(encoding='utf-8'))
print(f'Confirmed pairs: {pair_count:,}')

# %% [markdown]
# ## Create Hugging Face Classifier Repo
#
# Run this once per target repo. Set `private=True` if you do not want the classifier public yet. The cell is safe to rerun because `exist_ok=True`.

# %%
from huggingface_hub import create_repo

create_repo(HF_CLASSIFIER_REPO, repo_type='model', exist_ok=True, private=False)
print(f'Ready: https://huggingface.co/{HF_CLASSIFIER_REPO}')

# %% [markdown]
# ## Push Classifier To Hugging Face

# %%
from framework.classifier import ResolvedThreadClassifier

if not CLASSIFIER_DIR.exists():
    raise FileNotFoundError(CLASSIFIER_DIR)
ResolvedThreadClassifier(str(CLASSIFIER_DIR)).load().push_to_hub(HF_CLASSIFIER_REPO)
print(f'Pushed classifier: https://huggingface.co/{HF_CLASSIFIER_REPO}')
